# %%
import pandas as pd

# %%
df = pd.read_csv('ControlofCorruption.csv')

# %%
df = df.dropna(thresh=21)

# %%
df
# Out:
#      Unnamed: 0.1            Unnamed: 0      2002      2003      2004  \
# 1               2               Andorra  1.310744  1.332790  1.119150
# 2               3           Afghanistan -1.251137 -1.344180 -1.350647
# 3               4                Angola -1.155493 -1.335463 -1.377569
# 5               6               Albania -0.845341 -0.853787 -0.723732
# 7               8  United Arab Emirates  1.111619  0.826037  1.039477
# ..            ...                   ...       ...       ...       ...
# 209           210                Serbia -0.895785 -0.494189 -0.493294
# 210           211          South Africa  0.332902  0.275541  0.397753
# 211           212      Congo, Dem. Rep. -1.449971 -1.526455 -1.444694
# 212           213                Zambia -0.758519 -0.641859 -0.604488
# 213           214              Zimbabwe -1.156760 -1.188868 -1.253563
#
#          2005      2006      2007      2008      2009  ...      2012  \
# ...

# %%
df = pd.read_csv('GovernmentEffectiveness.csv')
df.dropna(thresh=21).count()
# Out:
# Unnamed: 0.1    186
# Unnamed: 0      186
# 2002            186
# 2003            186
# 2004            186
# 2005            186
# 2006            186
# 2007            186
# 2008            186
# 2009            186
# 2010            186
# 2011            186
# 2012            186
# 2013            186
# 2014            186
# 2015            186
# 2016            186
# 2017            186
# 2018            186
# 2019            186
# 2020            186
# 2021            186
# dtype: int64

# %%
df = pd.read_csv('PoliticalStability.csv')
df.dropna(thresh=22).count()
# Out:
# Unnamed: 0.1    190
# Unnamed: 0      190
# 2002            190
# 2003            190
# 2004            190
# 2005            190
# 2006            190
# 2007            190
# 2008            190
# 2009            190
# 2010            190
# 2011            190
# 2012            190
# 2013            190
# 2014            190
# 2015            190
# 2016            190
# 2017            190
# 2018            190
# 2019            190
# 2020            190
# 2021            190
# dtype: int64

# %%
df = pd.read_csv('RegulatoryQuality.csv')
df.dropna(thresh=21).count()
# Out:
# Unnamed: 0.1    186
# Unnamed: 0      186
# 2002            186
# 2003            186
# 2004            186
# 2005            186
# 2006            186
# 2007            186
# 2008            186
# 2009            186
# 2010            186
# 2011            186
# 2012            186
# 2013            186
# 2014            186
# 2015            186
# 2016            186
# 2017            186
# 2018            186
# 2019            186
# 2020            186
# 2021            186
# dtype: int64

# %%
df = pd.read_csv('RuleofLaw.csv')
df.dropna(thresh=21).count()
# Out:
# Unnamed: 0.1    200
# Unnamed: 0      200
# 2002            200
# 2003            200
# 2004            200
# 2005            200
# 2006            200
# 2007            200
# 2008            200
# 2009            200
# 2010            200
# 2011            200
# 2012            200
# 2013            200
# 2014            200
# 2015            200
# 2016            200
# 2017            200
# 2018            200
# 2019            200
# 2020            200
# 2021            200
# dtype: int64

# %%
df = pd.read_csv('VoiceandAccountability.csv')
df.dropna(thresh=21).count()
# Out:
# Unnamed: 0.1    200
# Unnamed: 0      200
# 2002            200
# 2003            200
# 2004            200
# 2005            200
# 2006            200
# 2007            200
# 2008            200
# 2009            200
# 2010            200
# 2011            200
# 2012            200
# 2013            200
# 2014            200
# 2015            200
# 2016            200
# 2017            200
# 2018            200
# 2019            200
# 2020            200
# 2021            200
# dtype: int64
