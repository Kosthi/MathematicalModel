# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./GovernmentEffectiveness.csv')
df1 = pd.read_excel('../指标总.xlsx')
lists = df1['Country Name'].tolist()
filled_df = pd.DataFrame()
k = []
for list in lists:
    flag = True
    for i in range(0, 214):
        if df.loc[i]['Country Name'] == list:
            flag = False
            filled_df = filled_df.append(df.loc[i])
            break
    if flag:
        print(list)
        tmp = df1[:]
        for i in range(0, 121):
            if tmp.loc[i]['Country Name'] == list:
                k.append(i)
df = filled_df

# %%
label = df.keys()[2:]
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
output = imputer.fit_transform(df[label])

# %%
df[label] = output

# %%
df = df.drop(df.keys()[-1], axis=1)

# %%
df
# Out:
#       Country Name      2002      2003      2004      2005      2006  \
# 5          Albania -0.624333 -0.569067 -0.409062 -0.704831 -0.586621
# 8        Argentina -0.228479 -0.032746  0.017336 -0.100426 -0.036109
# 9          Armenia -0.045769 -0.190818 -0.108693 -0.139262 -0.261046
# 12       Australia  1.659199  1.772497  1.984479  1.745690  1.707516
# 13         Austria  1.880228  1.929604  1.843320  1.679052  1.826992
# ..             ...       ...       ...       ...       ...       ...
# 202  Venezuela, RB -1.002944 -0.958337 -1.055545 -0.911587 -1.060597
# 204        Vietnam -0.437317 -0.415786 -0.493996 -0.232798 -0.251408
# 117         Kosovo       NaN -0.564559 -0.517124 -0.483087 -0.340270
# 210   South Africa  0.607831  0.602574  0.561649  0.569726  0.324347
# 212         Zambia -0.924903 -1.017558 -0.937764 -0.944814 -0.883436
#
#          2007      2008      2009      2010      2011      2012      2013  \
# 5   -0.431428 -0.370871 -0.254886 -0.278687 -0.200375 -0.267876 -0.323596
# 8   -0.011678 -0.124616 -0.295641 -0.111379 -0.071486 -0.206466 -0.253653
# 9   -0.377754 -0.170738 -0.019941 -0.166395 -0.108996 -0.026902  0.085327
# 12   1.818283  1.784160  1.701762  1.763190  1.689923  1.612834  1.632688
# 13   1.862880  1.771053  1.662538  1.812320  1.602670  1.559877  1.571748
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -1.092527 -1.144806 -0.968656 -1.097542 -1.127799 -1.078848 -1.110399
# 204 -0.235696 -0.210235 -0.250741 -0.248680 -0.214853 -0.259284 -0.255636
# 117 -0.202388 -0.230389 -0.409440 -0.590413 -0.439321 -0.324520 -0.355948
# 210  0.287497  0.337715  0.313202  0.192785  0.219012  0.171207  0.308264
# 212 -0.751893 -0.767481 -0.822768 -0.866416 -0.685642 -0.511381 -0.521591
#
#          2014      2015      2016      2017      2018      2019      2020
# 5   -0.048802  0.059288  0.059715  0.128730  0.110513 -0.033333 -0.124957
# 8   -0.109244 -0.016539  0.250169  0.164413  0.054248 -0.096507 -0.224287
# 9   -0.251769 -0.276716 -0.275093 -0.215339 -0.141409 -0.197479 -0.274477
# 12   1.601303  1.560223  1.561982  1.530469  1.588521  1.564876  1.610075
# 13   1.553547  1.477876  1.504636  1.499538  1.488016  1.521145  1.645901
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -1.169328 -1.158842 -1.236603 -1.397838 -1.644374 -1.694787 -1.871081
# 204 -0.050734  0.092466  0.028950  0.007790  0.002769  0.043868  0.230214
# 117 -0.288678 -0.393235 -0.404602 -0.387632 -0.417538 -0.340277 -0.298101
# 210  0.164873  0.116498  0.132853  0.100144  0.132597  0.162543  0.096806
# 212 -0.534560 -0.612142 -0.704611 -0.671801 -0.624778 -0.717326 -0.802456
#
# [121 rows x 20 columns]

# %%
df.to_csv('New_New_GovernmentEffectiveness.csv')

# %%
# 标准化
def standard(datas):
    k = np.power(np.sum(np.power(datas, 2)), 0.5)
    datas = datas / k
    return datas

# %%
label = df.keys()[2:]
list = []
for value in df[label].values:
    list.append(standard(value))

# %%
df[label] = list

# %%
df
# Out:
#       Country Name      2002      2003      2004      2005      2006  \
# 5          Albania -0.624333 -0.395531 -0.284319 -0.489893 -0.407731
# 8        Argentina -0.228479 -0.051474  0.027250 -0.157863 -0.056761
# 9          Armenia -0.045769 -0.220055 -0.125347 -0.160600 -0.301044
# 12       Australia  1.659199  0.248187  0.277869  0.244433  0.239088
# 13         Austria  1.880228  0.273563  0.261331  0.238042  0.259016
# ..             ...       ...       ...       ...       ...       ...
# 202  Venezuela, RB -1.002944 -0.182499 -0.201011 -0.173596 -0.201973
# 204        Vietnam -0.437317 -0.414860 -0.492896 -0.232280 -0.250848
# 117         Kosovo       NaN -0.331434 -0.303587 -0.283605 -0.199762
# 210   South Africa  0.607831  0.457545  0.426471  0.432603  0.246282
# 212         Zambia -0.924903 -0.316587 -0.291762 -0.293955 -0.274859
#
#          2007      2008      2009      2010      2011      2012      2013  \
# 5   -0.299865 -0.257774 -0.177159 -0.193702 -0.139271 -0.186187 -0.224915
# 8   -0.018357 -0.195888 -0.464727 -0.175079 -0.112372 -0.324550 -0.398725
# 9   -0.435635 -0.196899 -0.022997 -0.191890 -0.125697 -0.031024  0.098401
# 12   0.254598  0.249820  0.238283  0.246884  0.236625  0.225831  0.228611
# 13   0.264104  0.251085  0.235701  0.256936  0.227213  0.221146  0.222829
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.208053 -0.218009 -0.184464 -0.209008 -0.214770 -0.205449 -0.211457
# 204 -0.235171 -0.209767 -0.250183 -0.248126 -0.214375 -0.258707 -0.255067
# 117 -0.118815 -0.135254 -0.240369 -0.346613 -0.257911 -0.190515 -0.208966
# 210  0.218302  0.256433  0.237820  0.146385  0.166300  0.130000  0.234070
# 212 -0.233932 -0.238782 -0.255983 -0.269564 -0.213320 -0.159103 -0.162280
#
#          2014      2015      2016      2017      2018      2019      2020
# 5   -0.033920  0.041208  0.041505  0.089474  0.076812 -0.023168 -0.086851
# 8   -0.171724 -0.025998  0.393249  0.258446  0.085274 -0.151702 -0.352565
# 9   -0.290346 -0.319116 -0.317244 -0.248335 -0.163077 -0.227738 -0.316533
# 12   0.224216  0.218464  0.218710  0.214298  0.222426  0.219116  0.225444
# 13   0.220249  0.209521  0.213315  0.212592  0.210959  0.215655  0.233342
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.222679 -0.220682 -0.235490 -0.266195 -0.313143 -0.322744 -0.356316
# 204 -0.050621  0.092260  0.028885  0.007773  0.002763  0.043770  0.229701
# 117 -0.169474 -0.230855 -0.237529 -0.227566 -0.245123 -0.199766 -0.175005
# 210  0.125191  0.088459  0.100878  0.076041  0.100683  0.123422  0.073506
# 212 -0.166315 -0.190452 -0.219222 -0.209014 -0.194384 -0.223178 -0.249664
#
# [121 rows x 20 columns]

# %%
df.to_csv('New_GovernmentEffectiveness.csv')
