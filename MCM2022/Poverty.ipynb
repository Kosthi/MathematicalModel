# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('MCM2022F题数据/经济/Poverty headcount ratio at $2.15 a day (2017 PPP) (% of population).csv')
df1 = pd.read_csv('./Industry (including construction).csv')
lists = df1['Unnamed: 0'].tolist()
filled_df = pd.DataFrame()
for list in lists:
    filled_df = filled_df.append(df[list:list + 1])
filled_df
# Out:
#      Country Name Country Code  \
# 4          Angola          AGO
# 5         Albania          ALB
# 9       Argentina          ARG
# 10        Armenia          ARM
# 13      Australia          AUS
# ..            ...          ...
# 259         World          WLD
# 260         Samoa          WSM
# 263  South Africa          ZAF
# 264        Zambia          ZMB
# 265      Zimbabwe          ZWE
#
#                                         Indicator Name Indicator Code  1960  \
# 4    Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 5    Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 9    Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 10   Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 13   Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# ..                                                 ...            ...   ...
# 259  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 260  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 263  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 264  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
# 265  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY   NaN
#
#      1961  1962  1963  1964  1965  ...  2012  2013  2014  2015  2016  2017  \
# 4     NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 5     NaN   NaN   NaN   NaN   NaN  ...   0.6   NaN   1.0   0.1   0.1   0.4
# 9     NaN   NaN   NaN   NaN   NaN  ...   0.6   0.6   0.6   NaN   0.7   0.4
# 10    NaN   NaN   NaN   NaN   NaN  ...   0.8   1.7   1.4   1.1   1.1   0.8
# 13    NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   0.5   NaN   0.5   NaN
# ..    ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 259   NaN   NaN   NaN   NaN   NaN  ...  13.3  11.7  11.2  10.8  10.5   9.6
# 260   NaN   NaN   NaN   NaN   NaN  ...   NaN   1.2   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN  20.5   NaN   NaN   NaN
# 264   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN  61.4   NaN   NaN
# 265   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN  34.2
#
#      2018  2019  2020  2021
# 4    31.1   NaN   NaN   NaN
# 5     0.0   0.0   NaN   NaN
# 9     0.8   0.8   1.1   NaN
# 10    1.3   1.0   0.4   NaN
# 13    0.5   NaN   NaN   NaN
# ..    ...   ...   ...   ...
# 259   8.9   8.4   NaN   NaN
# 260   NaN   NaN   NaN   NaN
# 263   NaN   NaN   NaN   NaN
# 264   NaN   NaN   NaN   NaN
# 265   NaN  39.8   NaN   NaN
#
# [146 rows x 66 columns]

# %%
#df = df.dropna(how='all', subset=df.keys()[4:66])
filled_df = filled_df.dropna(thresh=3, subset=df.keys()[4:66])
filled_df.count()

m=filled_df[filled_df.keys()[4:66]].mean(axis=1)
filled_df=filled_df.fillna({x:m for x in filled_df.keys()[4:66]})
filled_df
# filled_df.to_csv('Poverty headcount ratio.csv')
# Out:
#      Country Name Country Code  \
# 4          Angola          AGO
# 5         Albania          ALB
# 9       Argentina          ARG
# 10        Armenia          ARM
# 13      Australia          AUS
# ..            ...          ...
# 259         World          WLD
# 260         Samoa          WSM
# 263  South Africa          ZAF
# 264        Zambia          ZMB
# 265      Zimbabwe          ZWE
#
#                                         Indicator Name Indicator Code  \
# 4    Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 5    Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 9    Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 10   Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 13   Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# ..                                                 ...            ...
# 259  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 260  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 263  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 264  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
# 265  Poverty headcount ratio at $2.15 a day (2017 P...    SI.POV.DDAY
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 4    22.366667  22.366667  22.366667  22.366667  22.366667  22.366667  ...
# 5     0.418182   0.418182   0.418182   0.418182   0.418182   0.418182  ...
# 9     2.515625   2.515625   2.515625   2.515625   2.515625   2.515625  ...
# 10    3.271429   3.271429   3.271429   3.271429   3.271429   3.271429  ...
# 13    0.666667   0.666667   0.666667   0.666667   0.666667   0.666667  ...
# ..         ...        ...        ...        ...        ...        ...  ...
# 259  26.800000  26.800000  26.800000  26.800000  26.800000  26.800000  ...
# 260   1.500000   1.500000   1.500000   1.500000   1.500000   1.500000  ...
# 263  25.983333  25.983333  25.983333  25.983333  25.983333  25.983333  ...
# 264  58.066667  58.066667  58.066667  58.066667  58.066667  58.066667  ...
# 265  31.866667  31.866667  31.866667  31.866667  31.866667  31.866667  ...
#
#           2012       2013       2014       2015       2016       2017  \
# 4    22.366667  22.366667  22.366667  22.366667  22.366667  22.366667
# 5     0.600000   0.418182   1.000000   0.100000   0.100000   0.400000
# 9     0.600000   0.600000   0.600000   2.515625   0.700000   0.400000
# 10    0.800000   1.700000   1.400000   1.100000   1.100000   0.800000
# 13    0.666667   0.666667   0.500000   0.666667   0.500000   0.666667
# ..         ...        ...        ...        ...        ...        ...
# 259  13.300000  11.700000  11.200000  10.800000  10.500000   9.600000
# 260   1.500000   1.200000   1.500000   1.500000   1.500000   1.500000
# 263  25.983333  25.983333  20.500000  25.983333  25.983333  25.983333
# 264  58.066667  58.066667  58.066667  61.400000  58.066667  58.066667
# 265  31.866667  31.866667  31.866667  31.866667  31.866667  34.200000
#
#           2018       2019       2020       2021
# 4    31.100000  22.366667  22.366667  22.366667
# 5     0.000000   0.000000   0.418182   0.418182
# 9     0.800000   0.800000   1.100000   2.515625
# 10    1.300000   1.000000   0.400000   3.271429
# 13    0.500000   0.666667   0.666667   0.666667
# ..         ...        ...        ...        ...
# 259   8.900000   8.400000  26.800000  26.800000
# 260   1.500000   1.500000   1.500000   1.500000
# 263  25.983333  25.983333  25.983333  25.983333
# 264  58.066667  58.066667  58.066667  58.066667
# 265  31.866667  39.800000  31.866667  31.866667
#
# [146 rows x 66 columns]

# %%
filled_df.keys()[4:66]
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %%
filled_df = filled_df.drop(filled_df.keys()[1:60], axis=1)
filled_df = filled_df.drop(filled_df.keys()[-1], axis=1)

# %%
filled_df.count()
# Out:
# Country Name    146
# 2016            146
# 2017            146
# 2018            146
# 2019            146
# 2020            146
# dtype: int64

# %%
filled_df.to_csv('Poverty headcount ratio.csv')
