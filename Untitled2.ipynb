# %%
import warnings
import pandas as pd
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('rankt.csv')

# %%
df.describe()
# Out:
#        Unnamed: 0  ControlofCorruption  PoliticalStability  \
# count  121.000000           121.000000          121.000000
# mean    60.000000             0.000595           -0.012964
# std     35.073732             0.091285            0.090354
# min      0.000000            -0.148105           -0.236953
# 25%     30.000000            -0.069446           -0.066843
# 50%     60.000000            -0.025743           -0.013527
# 75%     90.000000             0.059819            0.059053
# max    120.000000             0.215628            0.153438
#
#        GovernmentEffectiveness  RegulatoryQuality   RuleofLaw  \
# count               121.000000         121.000000  121.000000
# mean                  0.010077           0.012400    0.001862
# std                   0.090725           0.090434    0.091268
# min                  -0.193575          -0.232951   -0.231142
# 25%                  -0.063494          -0.055661   -0.062043
# ...
