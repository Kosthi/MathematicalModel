# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./PoliticalStability.csv')
df1 = pd.read_excel('../指标总.xlsx')
lists = df1['Country Name'].tolist()
filled_df = pd.DataFrame()
k = []
for list in lists:
    flag = True
    for i in range(0, 214):
        if df.loc[i]['Country Name'] == list:
            flag = False
            filled_df = filled_df.append(df.loc[i])
            break
    if flag:
        print(list)
        tmp = df1[:]
        for i in range(0, 121):
            if tmp.loc[i]['Country Name'] == list:
                k.append(i)
df = filled_df

# %%
label = df.keys()[2:]
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
output = imputer.fit_transform(df[label])

# %%
df[label] = output

# %%
df = df.drop(df.keys()[0], axis=1)
df = df.drop(df.keys()[-1], axis=1)

# %%
df
# Out:
#       Country Name      2002      2003      2004      2005      2006  \
# 5          Albania -0.297719 -0.309780 -0.427260 -0.505048 -0.508157
# 8        Argentina -0.776545 -0.359838 -0.610935 -0.041775  0.001968
# 9          Armenia -0.255784  0.236966 -0.116337 -0.066335 -0.261024
# 12       Australia  1.189415  0.878117  0.935464  0.891708  0.934467
# 13         Austria  1.358955  0.962002  1.089649  1.103950  1.074451
# ..             ...       ...       ...       ...       ...       ...
# 202  Venezuela, RB -1.317897 -1.286445 -1.391586 -1.244332 -1.252868
# 204        Vietnam  0.353681  0.126424  0.150154  0.484038  0.405120
# 117         Kosovo -0.165204 -0.003728 -0.119710 -0.263039 -0.516594
# 210   South Africa -0.254790 -0.312843 -0.131730 -0.162092  0.047030
# 212         Zambia -0.274405  0.218380  0.190814  0.108463  0.363792
#
#          2007      2008      2009      2010      2011      2012      2013  \
# 5   -0.203975 -0.030501 -0.045141 -0.191483 -0.282379 -0.143632  0.091930
# 8    0.097797 -0.087756 -0.234855 -0.084798  0.158994  0.103041  0.065314
# 9    0.150906 -0.006853  0.227863  0.071855 -0.063869  0.154795  0.110385
# 12   0.928875  0.954700  0.855121  0.888860  0.935710  0.997997  1.031073
# 13   1.284419  1.339271  1.190874  1.152648  1.193522  1.340567  1.364101
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -1.229670 -1.312439 -1.277789 -1.256237 -1.094046 -1.027133 -1.077632
# 204  0.251872  0.165261  0.271776  0.148408  0.189088  0.267359  0.250577
# 117 -0.126358  1.012083  0.430509 -1.044821 -1.042147 -1.038502 -0.966147
# 210  0.215347  0.049529 -0.114493 -0.029427  0.024032 -0.025387 -0.046295
# 212  0.363629  0.472573  0.569586  0.515351  0.509774  0.660963  0.435933
#
#          2014      2015      2016      2017      2018      2019      2020
# 5    0.485986  0.346129  0.344645  0.378475  0.370516  0.111169  0.087552
# 8   -0.005122  0.014785  0.204626  0.169504  0.010891 -0.091444 -0.079214
# 9   -0.297136 -0.252333 -0.662264 -0.620771 -0.444908 -0.413424 -0.760855
# 12   1.032192  0.884980  1.047958  0.896061  0.989604  0.911746  0.850844
# 13   1.270700  1.143079  0.909639  1.046833  0.902334  0.916748  0.912809
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.852002 -0.977181 -1.024604 -1.272082 -1.351146 -1.536778 -1.550175
# 204 -0.022347  0.069970  0.233592  0.230204  0.058509  0.025496 -0.079573
# 117 -0.340775 -0.199357 -0.282407 -0.246100 -0.673299 -0.331690 -0.260956
# 210 -0.146389 -0.212993 -0.141504 -0.277562 -0.227779 -0.267670 -0.240825
# 212  0.156212  0.151695  0.142808  0.146243  0.085604 -0.113847 -0.130104
#
# [121 rows x 20 columns]

# %%
df.to_csv('New_New_PoliticalStability.csv')

# %%
# 标准化
def standard(datas):
    k = np.power(np.sum(np.power(datas, 2)), 0.5)
    datas = datas / k
    return datas

# %%
label = df.keys()[2:]
list = []
for value in df[label].values:
    list.append(standard(value))

# %%
df[label] = list

# %%
df
# Out:
#       Country Name      2002      2003      2004      2005      2006  \
# 5          Albania -0.297719 -0.233692 -0.322317 -0.380999 -0.383344
# 8        Argentina -0.776545 -0.427094 -0.725122 -0.049583  0.002336
# 9          Armenia -0.255784  0.160272 -0.078685 -0.044866 -0.176544
# 12       Australia  1.189415  0.220711  0.235125  0.224127  0.234875
# 13         Austria  1.358955  0.200196  0.226760  0.229736  0.223597
# ..             ...       ...       ...       ...       ...       ...
# 202  Venezuela, RB -1.317897 -0.245283 -0.265330 -0.237253 -0.238881
# 204        Vietnam  0.353681  0.132024  0.156805  0.505479  0.423065
# 117         Kosovo -0.165204 -0.001441 -0.046271 -0.101672 -0.199677
# 210   South Africa -0.254790 -0.419833 -0.176780 -0.217527  0.063114
# 212         Zambia -0.274405  0.147670  0.129030  0.073344  0.245998
#
#          2007      2008      2009      2010      2011      2012      2013  \
# 5   -0.153875 -0.023009 -0.034053 -0.144451 -0.213022 -0.108353  0.069350
# 8    0.116075 -0.104158 -0.278750 -0.100647  0.188710  0.122299  0.077522
# 9    0.102065 -0.004635  0.154116  0.048599 -0.043198  0.104696  0.074659
# 12   0.233469  0.239960  0.214931  0.223412  0.235187  0.250843  0.259156
# 13   0.267292  0.278707  0.247825  0.239870  0.248376  0.278977  0.283874
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.234458 -0.250239 -0.243633 -0.239523 -0.208599 -0.195841 -0.205469
# 204  0.263029  0.172581  0.283815  0.154982  0.197464  0.279202  0.261677
# 117 -0.048841  0.391197  0.166403 -0.403851 -0.402818 -0.401409 -0.373442
# 210  0.288994  0.066468 -0.153648 -0.039491  0.032250 -0.034069 -0.062127
# 212  0.245888  0.319557  0.385158  0.348484  0.344712  0.446947  0.294781
#
#          2014      2015      2016      2017      2018      2019      2020
# 5    0.366619  0.261113  0.259994  0.285514  0.279510  0.083864  0.066048
# 8   -0.006079  0.017549  0.242871  0.201185  0.012927 -0.108536 -0.094019
# 9   -0.200968 -0.170665 -0.447923 -0.419859 -0.300914 -0.279620 -0.514605
# 12   0.259438  0.222436  0.263400  0.225222  0.248733  0.229164  0.213857
# 13   0.264437  0.237879  0.189299  0.217849  0.187779  0.190778  0.189959
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.162449 -0.186316 -0.195358 -0.242544 -0.257619 -0.293013 -0.295568
# 204 -0.023337  0.073070  0.243939  0.240401  0.061100  0.026625 -0.083097
# 117 -0.131719 -0.077057 -0.109158 -0.095124 -0.260248 -0.128207 -0.100867
# 210 -0.196453 -0.285835 -0.189898 -0.372486 -0.305679 -0.359212 -0.323185
# 212  0.105632  0.102577  0.096568  0.098891  0.057886 -0.076984 -0.087977
#
# [121 rows x 20 columns]

# %%
df.to_csv('New_PoliticalStability.csv')
