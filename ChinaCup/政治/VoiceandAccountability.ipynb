# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./VoiceandAccountability.csv')
df1 = pd.read_excel('../指标总.xlsx')
lists = df1['Country Name'].tolist()
filled_df = pd.DataFrame()
k = []
for list in lists:
    flag = True
    for i in range(0, 214):
        if df.loc[i]['Country Name'] == list:
            flag = False
            filled_df = filled_df.append(df.loc[i])
            break
    if flag:
        print(list)
        tmp = df1[:]
        for i in range(0, 121):
            if tmp.loc[i]['Country Name'] == list:
                k.append(i)
df = filled_df

# %%
label = df.keys()[2:]
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
output = imputer.fit_transform(df[label])

# %%
df[label] = output

# %%
df = df.drop(df.keys()[0], axis=1)
df = df.drop(df.keys()[-1], axis=1)

# %%
df.to_csv('New_New_VoiceandAccountability.csv')

# %%
# 标准化
def standard(datas):
    k = np.power(np.sum(np.power(datas, 2)), 0.5)
    datas = datas / k
    return datas

# %%
label = df.keys()[2:]
list = []
for value in df[label].values:
    list.append(standard(value))

# %%
df[label] = list

# %%
df
# Out:
#       Country Name      2002      2003      2004      2005      2006  \
# 5          Albania -0.008150  0.134506  0.013846  0.007025  0.145185
# 8        Argentina  0.260063  0.199029  0.206392  0.153484  0.229991
# 9          Armenia -0.444421 -0.180960 -0.221518 -0.228951 -0.287357
# 12       Australia  1.407233  0.242907  0.252915  0.253844  0.232913
# 13         Austria  1.307497  0.227496  0.249802  0.233383  0.232372
# ..             ...       ...       ...       ...       ...       ...
# 202  Venezuela, RB -0.462428 -0.103453 -0.140770 -0.149913 -0.146350
# 204        Vietnam -1.448819 -0.242413 -0.219978 -0.230683 -0.252947
# 117         Kosovo -0.390101 -0.293942 -0.330252 -0.340424 -0.461759
# 210   South Africa  0.659822  0.260730  0.266508  0.241662  0.242632
# 212         Zambia -0.317013 -0.304342 -0.368603 -0.357087 -0.172042
#
#          2007      2008      2009      2010      2011      2012      2013  \
# 5    0.216197  0.334676  0.270661  0.236915  0.119251  0.042211  0.093537
# 8    0.255750  0.204599  0.159675  0.206181  0.196644  0.168293  0.157905
# 9   -0.293999 -0.332038 -0.339313 -0.328125 -0.267441 -0.220870 -0.227661
# 12   0.230624  0.230434  0.233081  0.239141  0.244860  0.252519  0.241945
# 13   0.231793  0.229965  0.235785  0.242124  0.237410  0.245252  0.246572
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.175406 -0.176932 -0.200764 -0.204761 -0.219697 -0.213330 -0.223824
# 204 -0.251055 -0.246084 -0.243770 -0.246126 -0.239910 -0.233483 -0.224658
# 117 -0.285607 -0.286816 -0.106801 -0.165433 -0.215791 -0.204535 -0.228912
# 210  0.215506  0.214346  0.212438  0.224191  0.220002  0.216768  0.223675
# 212 -0.171749 -0.133676 -0.249199 -0.201646 -0.141410 -0.110215 -0.087990
#
#          2014      2015      2016      2017      2018      2019      2020
# 5    0.275061  0.300666  0.327042  0.389901  0.345754  0.273021  0.169046
# 8    0.196871  0.234760  0.281258  0.301381  0.302400  0.326305  0.335272
# 9   -0.217611 -0.207627 -0.224258 -0.217116 -0.053407  0.021480  0.018991
# 12   0.229368  0.228335  0.228012  0.231708  0.232540  0.213476  0.219571
# 13   0.235531  0.234212  0.226412  0.234612  0.234919  0.226627  0.236768
# ..        ...       ...       ...       ...       ...       ...       ...
# 202 -0.254915 -0.256637 -0.267067 -0.283925 -0.338040 -0.336459 -0.356584
# 204 -0.226025 -0.223419 -0.225805 -0.232007 -0.242755 -0.231107 -0.226627
# 117 -0.183992 -0.137853 -0.135947 -0.105549 -0.132097 -0.105480 -0.144766
# 210  0.238447  0.241504  0.241416  0.234761  0.233948  0.243400  0.260717
# 212 -0.090802 -0.055216 -0.249445 -0.278432 -0.284302 -0.256932 -0.355669
#
# [121 rows x 20 columns]

# %%
df.to_csv('New_VoiceandAccountability.csv')
