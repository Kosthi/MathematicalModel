# %%
import pandas as pd
import numpy as np

# %%
df_pol_1 = pd.read_csv('./政治/New_New_ControlofCorruption.csv').sort_values(by='Country Name')
df_pol_2 = pd.read_csv('./政治/New_New_PoliticalStability.csv').sort_values(by='Country Name')
df_pol_3 = pd.read_csv('./政治/New_New_GovernmentEffectiveness.csv').sort_values(by='Country Name')
df_pol_4 = pd.read_csv('./政治/New_New_RegulatoryQuality.csv').sort_values(by='Country Name')
df_pol_5 = pd.read_csv('./政治/New_New_RuleofLaw.csv').sort_values(by='Country Name')
df_pol_6 = pd.read_csv('./政治/New_New_VoiceandAccountability.csv').sort_values(by='Country Name')

df_eco_1 = pd.read_csv('./经济/New_New_GDP per capita.csv').sort_values(by='Country Name')
df_eco_2 = pd.read_csv('./经济/New_New_GDP growth.csv').sort_values(by='Country Name')
df_eco_3 = pd.read_csv('./经济/New_New_debt index.csv').sort_values(by='Country Name')
df_eco_4 = pd.read_csv('./经济/New_New_Inflation rate.csv').sort_values(by='Country Name')
df_eco_5 = pd.read_csv('./经济/New_New_fiscal balance index.csv').sort_values(by='Country Name')
df_eco_6 = pd.read_csv('./经济/New_New_trade index.csv').sort_values(by='Country Name')

df_soc_1 = pd.read_csv('./社会/New_New_unemployment.csv').sort_values(by='Country Name')
df_soc_2 = pd.read_csv('./社会/New_New_School enrollment.csv').sort_values(by='Country Name')
df_soc_3 = pd.read_csv('./社会/New_New_Life expectancy.csv').sort_values(by='Country Name')
df_soc_4 = pd.read_csv('./社会/New_New_Intentional homicides.csv').sort_values(by='Country Name')
df_soc_5 = pd.read_csv('./社会/New_New_gini index.csv').sort_values(by='Country Name')

# %%
# for i in range(2002, 2021):
year = 2002
data = f'{year}'
df = pd.DataFrame()
labelind = pd.read_csv('./score_sort.csv').keys()[1:-2]
df[labelind[0]] = df_pol_1[labelind[0]]
labeldate = df_pol_1.keys()[2:-1]

df[labelind[1]] = df_pol_1[labeldate[0]]
df[labelind[2]] = df_pol_2[labeldate[0]]
df[labelind[3]] = df_pol_3[labeldate[0]]
df[labelind[4]] = df_pol_4[labeldate[0]]
df[labelind[5]] = df_pol_5[labeldate[0]]
df[labelind[6]] = df_pol_6[labeldate[0]]

# %%
df[labelind[7]] = df_eco_1[labeldate[0]]
df[labelind[8]] = df_eco_2[labeldate[0]]
df[labelind[9]] = df_eco_3[labeldate[0]]
df[labelind[10]] = df_eco_4[labeldate[0]]
df[labelind[11]] = df_eco_5[labeldate[0]]
df[labelind[12]] = df_eco_6[labeldate[0]]

# %%
df[labelind[13]] = df_soc_1[labeldate[0]]
df[labelind[14]] = df_soc_2[labeldate[0]]
df[labelind[15]] = df_soc_3[labeldate[0]]
df[labelind[16]] = df_soc_4[labeldate[0]]
df[labelind[17]] = df_soc_5[labeldate[0]]

# %%
df
# Out:
#            Country Name  ControlofCorruption  PoliticalStability  \
# 88              Albania            -0.845341           -0.058308
# 61            Argentina            -0.417056           -0.254790
# 80              Armenia            -0.778165           -1.038219
# 9             Australia             1.761436            1.218032
# 12              Austria             1.915159            1.303833
# ..                  ...                  ...                 ...
# 115          Uzbekistan            -0.964739           -1.956714
# 119       Venezuela, RB            -1.061424           -1.626329
# 77              Vietnam            -0.560991           -0.261419
# 55   West Bank and Gaza            -0.329601           -0.047421
# 73               Zambia            -0.758519           -0.253289
#
#      GovernmentEffectiveness  RegulatoryQuality  RuleofLaw  \
# 88                 -0.549481          -0.573990  -0.646826
# 61                 -0.563407           0.124769  -0.069342
# 80                 -0.231616          -0.237843  -0.782026
# 9                  -0.846448           1.719497   1.767047
# 12                 -1.071950           1.538056   1.634390
# ..                       ...                ...        ...
# 115                -1.208393          -1.346472  -1.083541
# 119                 0.607831          -1.510511  -1.107601
# 77                       NaN           0.149916  -0.386543
# 55                  1.030794          -0.157631  -0.049011
# 73                  0.218387          -0.582766  -0.341501
#
#      VoiceandAccountability  GDP per capita  GDP growth  debt index  \
# 88                 0.321517      434.810292  -12.407971   52.881483
# 61                -0.165571     1989.135125   -0.114221   55.361753
# 80                -0.492930     1156.217473    3.993590   41.352717
# 9                  1.407233    29343.245000    5.533342    4.429485
# 12                 1.377452    24255.338580    7.093195   39.125864
# ..                      ...             ...         ...         ...
# 115               -1.075241      303.665132    2.730948   53.862514
# 119               -1.738893      296.639568    0.253943   56.299406
# 77                -0.088549      911.911133    4.096777   62.552771
# 55                 0.380685     1479.314583    2.035863   55.361753
# 73                -0.387817     1682.994501    4.380099   55.361753
#
#      Inflation rate  fiscal balance  trade index  unemployment  \
# 88         8.609125       -4.568473   102.442049     18.110001
# 61        12.484019       -4.735704   102.214605      5.410000
# 80         9.167520       -3.959800   104.357067      4.220000
# 9          2.424437        1.506627    92.022740      3.265000
# 12         2.337302        0.401552   105.872434      2.750000
# ..              ...             ...          ...           ...
# 115       14.744635       -6.904442   100.395119     16.415000
# 119       14.335934      -10.881265    92.072257     31.940001
# 77        22.539886       -1.841200    91.940236     10.140000
# 55         1.832994       -1.854854   100.007876      6.780000
# 73         2.455357       -0.958147    97.783464     12.550000
#
#      School enrollment  Life expectancy  Intentional homicides  gini index
# 88           11.851470        63.616000               6.329669       45.20
# 61           20.695669        70.969000               8.234034       32.80
# 80           10.461150        65.950000               8.938996       42.00
# 9            63.508362        79.490244               0.634502       27.80
# 12           63.070080        78.292683               2.394006       33.65
# ..                 ...              ...                    ...         ...
# 115           1.009220        52.222000               4.160258       55.70
# 119           1.154100        44.486000              46.701135       58.10
# 77           16.964015        66.239000               4.401904       40.80
# 55           16.750299        70.445000               3.371527       34.80
# 73           14.803450        68.386000               9.920857       40.75
#
# [121 rows x 18 columns]

# %%
def minToMax(datas):
    return datas.max() - datas
df['debt index'] = minToMax(df['debt index'])
df['Intentional homicides'] = minToMax(df['Intentional homicides'])

def interToMax(datas, a, b):
    M = max(a - datas.min(), datas.max() - b)
    ans = []
    for data in datas:
        if data < a:
            ans.append(1 - (a - data) / M)
        elif data > b:
            ans.append(1 - (data - b) / M)
        else:
            ans.append(1)
    return ans

df['Inflation rate'] = interToMax(df['Inflation rate'], 3, 5)
df['unemployment'] = interToMax(df['unemployment'], 4, 8)
df['gini index'] = interToMax(df['gini index'], 30, 40)

# %%
df
# Out:
#            Country Name  ControlofCorruption  PoliticalStability  \
# 88              Albania            -0.845341           -0.058308
# 61            Argentina            -0.417056           -0.254790
# 80              Armenia            -0.778165           -1.038219
# 9             Australia             1.761436            1.218032
# 12              Austria             1.915159            1.303833
# ..                  ...                  ...                 ...
# 115          Uzbekistan            -0.964739           -1.956714
# 119       Venezuela, RB            -1.061424           -1.626329
# 77              Vietnam            -0.560991           -0.261419
# 55   West Bank and Gaza            -0.329601           -0.047421
# 73               Zambia            -0.758519           -0.253289
#
#      GovernmentEffectiveness  RegulatoryQuality  RuleofLaw  \
# 88                 -0.549481          -0.573990  -0.646826
# 61                 -0.563407           0.124769  -0.069342
# 80                 -0.231616          -0.237843  -0.782026
# 9                  -0.846448           1.719497   1.767047
# 12                 -1.071950           1.538056   1.634390
# ..                       ...                ...        ...
# 115                -1.208393          -1.346472  -1.083541
# 119                 0.607831          -1.510511  -1.107601
# 77                       NaN           0.149916  -0.386543
# 55                  1.030794          -0.157631  -0.049011
# 73                  0.218387          -0.582766  -0.341501
#
#      VoiceandAccountability  GDP per capita  GDP growth  debt index  \
# 88                 0.321517      434.810292  -12.407971   74.895984
# 61                -0.165571     1989.135125   -0.114221   72.415714
# 80                -0.492930     1156.217473    3.993590   86.424750
# 9                  1.407233    29343.245000    5.533342  123.347982
# 12                 1.377452    24255.338580    7.093195   88.651603
# ..                      ...             ...         ...         ...
# 115               -1.075241      303.665132    2.730948   73.914953
# 119               -1.738893      296.639568    0.253943   71.478061
# 77                -0.088549      911.911133    4.096777   65.224696
# 55                 0.380685     1479.314583    2.035863   72.415714
# 73                -0.387817     1682.994501    4.380099   72.415714
#
#      Inflation rate  fiscal balance  trade index  unemployment  \
# 88         0.903853       -4.568473   102.442049      0.784894
# 61         0.800626       -4.735704   102.214605      1.000000
# 80         0.888977       -3.959800   104.357067      1.000000
# 9          0.984667        1.506627    92.022740      0.984362
# 12         0.982346        0.401552   105.872434      0.973404
# ..              ...             ...          ...           ...
# 115        0.740403       -6.904442   100.395119      0.820957
# 119        0.751291      -10.881265    92.072257      0.490638
# 77         0.532738       -1.841200    91.940236      0.954468
# 55         0.968911       -1.854854   100.007876      1.000000
# 73         0.985491       -0.958147    97.783464      0.903191
#
#      School enrollment  Life expectancy  Intentional homicides  gini index
# 88           11.851470        63.616000              63.118033    0.789474
# 61           20.695669        70.969000              61.213667    1.000000
# 80           10.461150        65.950000              60.508705    0.919028
# 9            63.508362        79.490244              68.813199    0.910931
# 12           63.070080        78.292683              67.053695    1.000000
# ..                 ...              ...                    ...         ...
# 115           1.009220        52.222000              65.287443    0.364372
# 119           1.154100        44.486000              22.746567    0.267206
# 77           16.964015        66.239000              65.045798    0.967611
# 55           16.750299        70.445000              66.076174    1.000000
# 73           14.803450        68.386000              59.526844    0.969636
#
# [121 rows x 18 columns]

# %%
def standard(datas):
    k = np.power(np.sum(np.power(datas, 2), axis=0), 0.5)
    for i in range(len(k)):
        datas[:, i] = datas[:, i] / k[i]
    return datas
label = df.keys()[1:]
data = standard(df[label].values)
df[label] = data

# %%
df
# Out:
#            Country Name  ControlofCorruption  PoliticalStability  \
# 88              Albania            -0.076388           -0.005626
# 61            Argentina            -0.037687           -0.024585
# 80              Armenia            -0.070318           -0.100180
# 9             Australia             0.159170            0.117530
# 12              Austria             0.173061            0.125810
# ..                  ...                  ...                 ...
# 115          Uzbekistan            -0.087177           -0.188807
# 119       Venezuela, RB            -0.095914           -0.156928
# 77              Vietnam            -0.050693           -0.025225
# 55   West Bank and Gaza            -0.029784           -0.004576
# 73               Zambia            -0.068543           -0.024440
#
#      GovernmentEffectiveness  RegulatoryQuality  RuleofLaw  \
# 88                       NaN          -0.058158  -0.061728
# 61                       NaN           0.012642  -0.006617
# 80                       NaN          -0.024099  -0.074631
# 9                        NaN           0.174223   0.168634
# 12                       NaN           0.155839   0.155974
# ..                       ...                ...        ...
# 115                      NaN          -0.136428  -0.103405
# 119                      NaN          -0.153048  -0.105701
# 77                       NaN           0.015190  -0.036889
# 55                       NaN          -0.015972  -0.004677
# 73                       NaN          -0.059047  -0.032590
#
#      VoiceandAccountability  GDP per capita  GDP growth  debt index  \
# 88                 0.031662        0.003008   -0.207744    0.089260
# 61                -0.016305        0.013763   -0.001912    0.086304
# 80                -0.048542        0.008000    0.066864    0.103000
# 9                  0.138580        0.203029    0.092644    0.147005
# 12                 0.135648        0.167825    0.118760    0.105654
# ..                      ...             ...         ...         ...
# 115               -0.105887        0.002101    0.045724    0.088091
# 119               -0.171241        0.002052    0.004252    0.085187
# 77                -0.008720        0.006310    0.068592    0.077734
# 55                 0.037489        0.010236    0.034086    0.086304
# 73                -0.038191        0.011645    0.073335    0.086304
#
#      Inflation rate  fiscal balance  trade index  unemployment  \
# 88         0.088051       -0.093991     0.094536      0.076397
# 61         0.077995       -0.097432     0.094326      0.097334
# 80         0.086601       -0.081468     0.096303      0.097334
# 9          0.095923        0.030997     0.084920      0.095811
# 12         0.095697        0.008261     0.097701      0.094745
# ..              ...             ...          ...           ...
# 115        0.072128       -0.142051     0.092647      0.079907
# 119        0.073188       -0.223870     0.084966      0.047756
# 77         0.051898       -0.037881     0.084844      0.092902
# 55         0.094388       -0.038162     0.092289      0.097334
# 73         0.096004       -0.019713     0.090237      0.087911
#
#      School enrollment  Life expectancy  Intentional homicides  gini index
# 88            0.029164         0.084184               0.092858    0.080463
# 61            0.050928         0.093915               0.090056    0.101919
# 80            0.025743         0.087273               0.089019    0.093667
# 9             0.156282         0.105191               0.101236    0.092841
# 12            0.155203         0.103606               0.098648    0.101919
# ..                 ...              ...                    ...         ...
# 115           0.002483         0.069106               0.096049    0.037137
# 119           0.002840         0.058869               0.033464    0.027233
# 77            0.041745         0.087655               0.095694    0.098618
# 55            0.041219         0.093221               0.097210    0.101919
# 73            0.036428         0.090496               0.087574    0.098825
#
# [121 rows x 18 columns]

# %%
label = df.keys()[1:7]
label
# Out:
# Index(['ControlofCorruption', 'PoliticalStability', 'GovernmentEffectiveness',
#        'RegulatoryQuality', 'RuleofLaw', 'VoiceandAccountability'],
#       dtype='object')

# %%
a = np.array(df[label])
a = a + abs(a.min(axis=0)) + 0.01
a
# Out:
# array([[0.06934422, 0.22483606,        nan, 0.1048904 , 0.09102926,
#         0.21983802],
#        [0.10804564, 0.20587715,        nan, 0.17569023, 0.14614006,
#         0.17187101],
#         0.23015146],
#        [0.06974266, 0.07110447,        nan, 0.14908538, 0.07642593,
#         0.12127055],
#        [0.05304275, 0.11364281,        nan, 0.05928047, 0.11667327,
#         0.08254896],
#        [0.04710997, 0.13567745,        nan, 0.09524393, 0.06930136,
#         0.06375523],
#        [0.23119313, 0.31135426,        nan, 0.2705392 , 0.27273911,
#         0.32058528],
#        [0.31503736, 0.29739652,        nan, 0.29664134, 0.26850501,
#         0.30185237],
#        [0.05855498, 0.04165499,        nan, 0.02662079, 0.04935247,
#         0.0822892 ],
#        [0.04981812, 0.07353452,        nan, 0.01      , 0.0470563 ,
#         0.01693463],
#        [0.09503914, 0.20523754,        nan, 0.17823813, 0.11586871,
#         0.17945589],
#        [0.11594833, 0.22588658,        nan, 0.14707683, 0.14808028,
#         0.22566479],
#        [0.06478593, 0.26209246,        nan, 0.10153951, 0.08795866,
#         0.14717423],
#        [0.17581451, 0.30973209,        nan, 0.19286555, 0.15537157,
#         0.23468064],
#        [0.07718975, 0.20602195,        nan, 0.10400119, 0.12016716,
#         0.14998485]])

# %%
[n, m] = a.shape
cs = a.sum(axis=0)
P = a / cs
e = -(P * np.log(P)).sum(axis=0) / np.log(n)
g = 1 - e
w = g / sum(g)

# %%
def score(datas):
    z_min = np.min(datas, axis = 0)
    z_max = np.max(datas, axis = 0)
    min_Distance = np.power(np.power(z_min - datas, 2) @ w, 0.5)
    max_Distance = np.power(np.power(z_max - datas, 2) @ w, 0.5)
    scores = min_Distance / (max_Distance + min_Distance)
    # scores = scores / np.sum(scores, axis = 0)
    return scores

df['得分'].min()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Project/MathModel/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/Project/MathModel/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Project/MathModel/venv/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '得分'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 10
#       7     # scores = scores / np.sum(scores, axis = 0)
#       8     return scores
# ---> 10 df['得分'].min()
#
# File ~/Project/MathModel/venv/lib/python3.9/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/Project/MathModel/venv/lib/python3.9/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: '得分'

# %%
df.sort_values(by='得分')

# %%
for i in range(12, 17):
    print(round(w[i] / np.sum(w[12:17], axis=0), 3))
# Out:
# 0.151
# 0.59
# 0.006
# 0.104
# 0.149

# %%
from matplotlib import pyplot as plt
import scipy.stats as sta
# SPSS 斯皮尔曼检验
statistic, pvalue = sta.spearmanr(df[label], axis = 0)
newdf = pd.read_excel('./p值检验.xlsx')
newdf[newdf.keys()[1:]] = pvalue

# plt.xlabel("X",size=20)
plt.ylabel(newdf.keys()[1:].all(), size=20, rotation=0)
plt.title("heatmap",size=20)

sns.heatmap(newdf[newdf.keys()[1:]] < 0.1, annot=True, vmin=0, vmax=1, annot_kws={'size':5})
# Out:
# <AxesSubplot: title={'center': 'heatmap'}>

# %%
# def score(datas):
#     z_min = np.min(datas, axis = 0)
#     z_max = np.max(datas, axis = 0)
#     min_Distance = np.power(np.sum(np.power(z_min - datas, 2), axis = 1), 0.5)
#     max_Distance = np.power(np.sum(np.power(z_max - datas, 2), axis = 1), 0.5)
#     scores = min_Distance / (max_Distance + min_Distance)
#     scores = scores / np.sum(scores, axis = 0)
#     return scores
# df['得分'] = score(df[label].values)
# df
# Out:
#      Unnamed: 0   Country Name  New_debt   New_fiscal balance  New_GDP growth  \
# 0             0        Albania   0.124328           -0.355177       -0.188921
# 1             1      Argentina   0.000000           -0.469513       -0.344053
# 2             2        Armenia   0.118864           -0.315966       -0.180688
# 3             3      Australia   0.000000           -0.586534       -0.004013
# 4             4        Austria   0.000000           -0.589116       -0.563875
# ..          ...            ...        ...                 ...             ...
# 116         116  Venezuela, RB   0.000000           -0.115929       -0.191718
# 117         117        Vietnam   0.000000           -0.214068        0.100890
# 118         118         Kosovo   0.000000           -0.544011       -0.268960
# 119         119   South Africa   0.000000           -0.569233       -0.424693
# 120         120         Zambia   0.000000           -0.442864       -0.101588
#
#      New_GDP per capita  New_Inflation rate  New_trade index  New_gini index  \
# 0              0.303033            0.181472         0.233899        0.046555
# 1              0.192839            0.252256         0.247934        0.235992
# 2              0.307158            0.184464         0.273453        0.000000
# 3              0.236486            0.000000         0.275670        0.179605
# 4              0.244945            0.138411         0.218090        0.065949
# ..                  ...                 ...              ...             ...
# 116            0.171664            0.253410         0.112828        0.218970
# 117            0.381984            0.263509         0.255304        0.182574
# 118            0.298295            0.173770         0.238092        0.089252
# 119            0.202315            0.278765         0.281856        0.293538
# 120            0.171013            0.130465         0.233305        0.200570
#
#      New_Intentional homicides  New_Life expectancy  New_School enrollment  \
# 0                     0.197244             0.180825               0.275626
# 1                     0.268521             0.182152               0.264838
# 2                     0.218812             0.180540               0.224808
# 3                     0.274751             0.185890               0.249426
# 4                     0.204565             0.184180               0.240671
# ..                         ...                  ...                    ...
# 116                   0.199016             0.176524               0.282603
# 117                   0.275277             0.186140               0.273652
# 118                   0.246959             0.182441               0.268332
# 119                   0.217919             0.193440               0.267267
# 120                   0.281444             0.211924               0.303698
#
#      New_unemployment  New_ControlofCorruption  New_GovernmentEffectiveness  \
# 0            0.209235                -0.200880                    -0.086851
# 1            0.149965                -0.086902                    -0.352565
# 2            0.177642                 0.007953                    -0.316533
# 3            0.170484                 0.205315                     0.225444
# 4            0.108994                 0.211034                     0.233342
# ..                ...                      ...                          ...
# 116          0.193879                -0.290707                    -0.356316
# 117          0.150976                -0.143965                     0.229701
# 118          0.211483                -0.188327                    -0.175005
# 119          0.164150                -0.012130                     0.073506
# 120          0.281350                -0.334436                    -0.249664
#
#      New_PoliticalStability  New_RegulatoryQuality  New_RuleofLaw  \
# 0                  0.066048               0.214521      -0.157995
# 1                 -0.094019              -0.166528      -0.185248
# 2                 -0.514605               0.240191      -0.065060
# 3                  0.213857               0.241566       0.220423
# 4                  0.189959               0.220273       0.229255
# ..                      ...                    ...            ...
# 116               -0.295568              -0.316073      -0.300675
# 117               -0.083097              -0.094763      -0.088747
# 118               -0.100867              -0.375931      -0.150123
# 119               -0.323185               0.017408      -0.376768
# 120               -0.087977              -0.280729      -0.348668
#
#      New_VoiceandAccountability        得分
# 0                      0.169046  0.008549
# 1                      0.335272  0.007235
# 2                      0.018991  0.007308
# 3                      0.219571  0.010344
# 4                      0.236768  0.009283
# ..                          ...       ...
# 116                   -0.356584  0.005908
# 117                   -0.226627  0.008821
# 118                   -0.144766  0.006017
# 119                    0.260717  0.007238
# 120                   -0.355669  0.005962
#
# [121 rows x 20 columns]

# %%
df.to_csv('score.csv')
