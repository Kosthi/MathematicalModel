# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('./fiscal balance index.csv')
df.keys()[13:]
# Out:
# Index(['2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020'],
#       dtype='object')

# %%
label = df.keys()[13:]
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=2)
output = imputer.fit_transform(df[label])

# %%
df[label] = output

# %%
df = df.drop(df.keys()[2:13], axis=1)
# df = df.drop(df.keys()[-1], axis=1)
df = df.drop(df.keys()[0], axis=1)

# %%
df.to_csv('New_New_fiscal balance index.csv')

# %%
# 标准化
def standard(datas):
    k = np.power(np.sum(np.power(datas, 2)), 0.5)
    datas = datas / k
    return datas
list = []
for value in df[label].values:
    list.append(standard(value))
df[label] = list

# %%
df
# Out:
#       Country Name      2002      2003      2004      2005      2006  \
# 0          Albania -0.328629 -0.264851 -0.273138 -0.182936 -0.172643
# 1        Argentina -0.104425  0.082011  0.216865  0.182627  0.090207
# 2          Armenia -0.356155 -0.225648 -0.165724 -0.166877 -0.114060
# 3        Australia  0.012908  0.070402  0.088664  0.114446  0.118799
# 4          Austria -0.136531 -0.101180 -0.354343 -0.186050 -0.187710
# ..             ...       ...       ...       ...       ...       ...
# 116  Venezuela, RB -0.034294  0.003966  0.057155  0.094733 -0.037124
# 117        Vietnam -0.137427 -0.189564 -0.011080 -0.070677  0.014861
# 118         Kosovo  0.234300  0.108382 -0.318803 -0.157760  0.182476
# 119   South Africa -0.056390 -0.093469 -0.061439 -0.006057  0.047955
# 120         Zambia -0.144558 -0.170758 -0.080601 -0.076219  0.543437
#
#          2007      2008      2009      2010      2011      2012      2013  \
# ...

# %%
df.to_csv('New_fiscal balance index.csv')
